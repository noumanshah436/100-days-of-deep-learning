# %% [markdown]
# <a href="https://colab.research.google.com/github/DatumLearning/Keras-Full-Course/blob/main/1_iris_simple_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/iris.csv")

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.columns = ["sepal_length" , "sepal_width" , "petal_length" , "petal_width" , "variety"]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      variety
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x = df.drop("variety" , axis = 1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.variety
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: variety, Length: 150, dtype: object

# %%
y = pd.get_dummies(df.variety)

# %%
y
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.3)

# %%
x_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 65            6.7          3.1           4.4          1.4
# 38            4.4          3.0           1.3          0.2
# 58            6.6          2.9           4.6          1.3
# 73            6.1          2.8           4.7          1.2
# 114           5.8          2.8           5.1          2.4

# %%
y_train
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 65             0                1               0
# 38             1                0               0
# 58             0                1               0
# 73             0                1               0
# 114            0                0               1
# ..           ...              ...             ...
# 32             1                0               0
# 135            0                0               1
# 8              1                0               0
# 88             0                1               0
# 39             1                0               0
#
# [105 rows x 3 columns]

# %%
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units = 6 , activation = "sigmoid"))
model.add(Dense(units = 3 , activation = 'softmax'))

# %%
model.compile(optimizer = 'rmsprop' , loss = 'categorical_crossentropy' , metrics = "accuracy")

# %%
model.fit(x_train , y_train , epochs = 25 , batch_size = 5)
# Out:
# Epoch 1/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8226 - accuracy: 0.7143
# Epoch 2/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8122 - accuracy: 0.7143
# Epoch 3/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8016 - accuracy: 0.7143
# Epoch 4/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7912 - accuracy: 0.7143
# Epoch 5/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7808 - accuracy: 0.7143
# Epoch 6/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7707 - accuracy: 0.7143
# Epoch 7/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7607 - accuracy: 0.7143
# Epoch 8/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7495 - accuracy: 0.7143
# Epoch 9/25
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7380 - accuracy: 0.7143
# Epoch 10/25
# ...

# %%
score = model.evaluate(x_test , y_test)
score
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6898 - accuracy: 0.5556
# [0.6897995471954346, 0.5555555820465088]

# %%
i = model.predict([[5.1 , 3.5 , 1.4 , 0.2]])
i
# Out:
# 1/1 [==============================] - 0s 97ms/step
# array([[0.8191691 , 0.14674439, 0.03408652]], dtype=float32)
